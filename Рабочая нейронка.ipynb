# %% [markdown]
# <a href="https://colab.research.google.com/github/agsystem72-crypto/data-analysis-/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%87%D0%B0%D1%8F%20%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BA%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Импортируем необходимые библиотеки
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.preprocessing.text import Tokenizer

# Загрузка и предобработка данных
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=1000)

# Создаем токенизатор
tokenizer = Tokenizer(num_words=1000)
x_train = tokenizer.sequences_to_matrix(x_train, mode='binary')
x_test = tokenizer.sequences_to_matrix(x_test, mode='binary')

# Создаем модель
model = Sequential()
model.add(Dense(512, input_shape=(1000,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# Компиляция модели
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Обучение модели
model.fit(x_train, y_train,
          batch_size=32,
          epochs=10,
          validation_data=(x_test, y_test))

# Функция для анализа названия фильма
def analyze_movie_title(title):
    # Преобразуем текст в последовательность
    title_seq = tokenizer.texts_to_sequences([title])
    # Векторизуем последовательность
    title_vec = tokenizer.sequences_to_matrix(title_seq, mode='binary')
    # Получаем предсказание
    prediction = model.predict(title_vec)[0][0]
    return "Положительный" if prediction >= 0.5 else "Отрицательный"

# Пример использования
movie_title = "The Shawshank Redemption"
result = analyze_movie_title(movie_title)
print(f"Название фильма: {movie_title}")
print(f"Прогноз: {result}")
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.7932 - loss: 0.4321 - val_accuracy: 0.8613 - val_loss: 0.3240
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8730 - loss: 0.3021 - val_accuracy: 0.8592 - val_loss: 0.3217
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8915 - loss: 0.2615 - val_accuracy: 0.8592 - val_loss: 0.3196
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9098 - loss: 0.2258 - val_accuracy: 0.8610 - val_loss: 0.3215
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9379 - loss: 0.1753 - val_accuracy: 0.8576 - val_loss: 0.3556
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9609 - loss: 0.1193 - val_accuracy: 0.8589 - val_loss: 0.3756
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9777 - loss: 0.0778 - val_accuracy: 0.8539 - val_loss: 0.4076
# Epoch 8/10
# ...
