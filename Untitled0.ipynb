# %% [markdown]
# <a href="https://colab.research.google.com/github/agsystem72-crypto/data-analysis-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# считывание данных из файла
insurance_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/insurance.csv')
# вывод переменной insurance_df
insurance_df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# Построение горизонтального бар-чарта
ax = insurance_df1.groupby('region').size().plot(
    kind='barh',
    color=sns.color_palette('Dark2'),
    figsize=(10, 6)
)

# Удаление верхних и правых границ
ax.spines[['top', 'right']].set_visible(False)

# Подписи и заголовок
ax.set_xlabel('Количество записей')
ax.set_ylabel('Регион')
ax.set_title('Распределение записей по регионам')

plt.show()
